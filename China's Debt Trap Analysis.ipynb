# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
import plotly.express as px

# %%
china_data = pd.read_csv("china_dept_trap.csv")

# %%
china_data.head()
# Out:
#                            Expand All | Collapse All  YEAR AMOUNT    LENDER  \
# 0            “Lar Patriota" Infrastructure (Phase 1)  2011   $50M       CDB
# 1  10-Year Oil Supply Plan (10Mt/Year), "Oil for ...  2009  $7.0B       CDB
# 2                               1000 housing project  2012   $47M  ExImBank
# 3  115kV Transmission Line and Substation from Ph...  2009  $475M  ExImBank
# 4            151 Multisector infrastructure projects  2016  $600M       CDB
#
#                   BORROWER                      SECTOR  \
# 0               Government                   Transport
# 1                Petrobras       Extraction, pipelines
# 2               Government                  Government
# 3  Electricite Du Cambodge                       Power
# 4    Central Bank of Kenya  Mulit-sector/discretionary
#
#   SENSITIVE TERRITORY OVERLAP   Country
# 0                  None Known    Angola
# 1                  None Known    Brazil
# 2                  None Known  Suriname
# 3                  None Known  Cambodia
# 4                  None Known     Kenya

# %%
china_data.tail()
# Out:
#                   Expand All | Collapse All  YEAR AMOUNT    LENDER  \
# 853  Zalingei-El Geneinah Road Construction  2009  $120M  ExImBank
# 854   Zanzibar Airport Terminal 2 Expansion  2010   $73M  ExImBank
# 855                      Zemun-Borca bridge  2009  $217M  ExImBank
# 856             Zongo II Hydropower Station  2011  $367M  ExImBank
# 857        Zungeru Hydropower Plant Project  2013  $984M  ExImBank
#
#        BORROWER     SECTOR       SENSITIVE TERRITORY OVERLAP  \
# 853  Government  Transport                        None Known
# 854  Government  Transport                        None Known
# 855  Government  Transport                        None Known
# 856  Government      Power                        None Known
# 857  Government      Power  Within Indigenous Peoples' Lands
#
#                                Country
# 853                              Sudan
# 854                           Tanzania
# 855                             Serbia
# 856  Congo, Democratic Republic of the
# 857                            Nigeria

# %%
china_data.shape
# Out:
# (858, 8)

# %%
china_data.columns
# Out:
# Index(['Expand All | Collapse All', 'YEAR', 'AMOUNT', 'LENDER', 'BORROWER',
#        'SECTOR', 'SENSITIVE TERRITORY OVERLAP', 'Country'],
#       dtype='object')

# %%
china_data = china_data.rename(columns = {'Expand All | Collapse All' : 'Title'})

# %%
china_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 858 entries, 0 to 857
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        858 non-null    object
#  1   YEAR                         858 non-null    int64
#  2   AMOUNT                       858 non-null    object
#  3   LENDER                       858 non-null    object
#  4   BORROWER                     857 non-null    object
#  5   SECTOR                       858 non-null    object
#  6   SENSITIVE TERRITORY OVERLAP  858 non-null    object
#  7   Country                      858 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 53.8+ KB

# %%
china_data.describe()
# Out:
#               YEAR
# count   858.000000
# mean   2013.268065
# std       2.894155
# min    2008.000000
# 25%    2011.000000
# 50%    2013.000000
# 75%    2016.000000
# max    2019.000000

# %%
china_data.isnull().sum()
# Out:
# Title                          0
# YEAR                           0
# AMOUNT                         0
# LENDER                         0
# BORROWER                       1
# SECTOR                         0
# SENSITIVE TERRITORY OVERLAP    0
# Country                        0
# dtype: int64

# %%
china_data.dropna(inplace = True)

# %%
china_data.nunique()
# Out:
# Title                          827
# YEAR                            12
# AMOUNT                         346
# LENDER                           7
# BORROWER                       120
# SECTOR                          10
# SENSITIVE TERRITORY OVERLAP      8
# Country                         94
# dtype: int64

# %%
china_data['YEAR'].unique()
# Out:
# array([2011, 2009, 2012, 2016, 2015, 2017, 2018, 2014, 2008, 2010, 2013,
#        2019], dtype=int64)

# %%
china_data['YEAR'].value_counts()
# Out:
# 2016    133
# 2011    106
# 2013     91
# 2012     86
# 2015     79
# 2017     75
# 2014     70
# 2009     69
# 2010     58
# 2018     45
# 2008     40
# 2019      5
# Name: YEAR, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot('YEAR', data = china_data, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
fig1 = px.histogram(china_data, x = 'YEAR', color = 'YEAR')
fig1.show()
# Out:
# <div>                            <div id="f660c545-920f-4f99-a576-409a46a692ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f660c545-920f-4f99-a576-409a46a692ea")) {                    Plotly.newPlot(                        "f660c545-920f-4f99-a576-409a46a692ea",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"YEAR=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2011","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2011","offsetgroup":"2011","orientation":"v","showlegend":true,"type":"histogram","x":[2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"YEAR=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2009","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2009","offsetgroup":"2009","orientation":"v","showlegend":true,"type":"histogram","x":[2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"YEAR=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2012","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"2012","offsetgroup":"2012","orientation":"v","showlegend":true,"type":"histogram","x":[2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"YEAR=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2016","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"2016","offsetgroup":"2016","orientation":"v","showlegend":true,"type":"histogram","x":[2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"YEAR=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2015","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"2015","offsetgroup":"2015","orientation":"v","showlegend":true,"type":"histogram","x":[2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015, ...

# %%
china_data['LENDER'].unique()
# Out:
# array(['CDB', 'ExImBank', 'CDB, ExImBank', 'BOC, CDB, ExImBank',
#        'CDB, ICBC', 'CDB, others', 'CDB, Citic'], dtype=object)

# %%
china_data['LENDER'].value_counts()
# Out:
# ExImBank              625
# CDB                   219
# CDB, ExImBank           8
# CDB, ICBC               2
# BOC, CDB, ExImBank      1
# CDB, others             1
# CDB, Citic              1
# Name: LENDER, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot('LENDER', data = china_data, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
fig2 = px.histogram(china_data, x = 'LENDER', color = 'LENDER')
fig2.show()
# Out:
# <div>                            <div id="a8a69f55-31af-4289-a588-47696a36856e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8a69f55-31af-4289-a588-47696a36856e")) {                    Plotly.newPlot(                        "a8a69f55-31af-4289-a588-47696a36856e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"LENDER=%{x}<br>count=%{y}<extra></extra>","legendgroup":"CDB","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CDB","offsetgroup":"CDB","orientation":"v","showlegend":true,"type":"histogram","x":["CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB","CDB"],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"LENDER=%{x}<br>count=%{y}<extra></extra>","legendgroup":"ExImBank","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ExImBank","offsetgroup":"ExImBank","orientation":"v","showlegend":true,"type":"histogram","x":["ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","ExImBank","E ...

# %%
china_data['SECTOR'].unique()
# Out:
# array(['Transport', 'Extraction, pipelines', 'Government', 'Power',
#        'Mulit-sector/discretionary', 'Telecom', 'Other construction',
#        'Agriculture, food', 'Manufacturing', 'fTransport'], dtype=object)

# %%
china_data['SECTOR'].value_counts()
# Out:
# Transport                     316
# Power                         203
# Government                    138
# Telecom                        63
# Extraction, pipelines          38
# Mulit-sector/discretionary     30
# Other construction             29
# Agriculture, food              27
# Manufacturing                  12
# fTransport                      1
# Name: SECTOR, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot('SECTOR', data = china_data, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
fig3 = px.histogram(china_data, x = 'SECTOR', color = 'SECTOR')
fig3.show()
# Out:
# <div>                            <div id="666a592d-460e-4992-b4b2-133e2a6279e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("666a592d-460e-4992-b4b2-133e2a6279e4")) {                    Plotly.newPlot(                        "666a592d-460e-4992-b4b2-133e2a6279e4",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"SECTOR=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Transport","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Transport","offsetgroup":"Transport","orientation":"v","showlegend":true,"type":"histogram","x":["Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transport","Transp ...

# %%
china_data['SENSITIVE TERRITORY OVERLAP'].unique()
# Out:
# array(['None Known',
#        "Within Indigenous Peoples' Lands\n Within Critical Habitats",
#        "Within Indigenous Peoples' Lands",
#        "Within Indigenous Peoples' Lands\n Within National Protected Areas",
#        'Within Critical Habitats\n Within National Protected Areas',
#        'Within Critical Habitats',
#        "Within Indigenous Peoples' Lands\n Within Critical Habitats\n Within National Protected Areas",
#        'Within National Protected Areas'], dtype=object)

# %%
china_data['SENSITIVE TERRITORY OVERLAP'].value_counts()
# Out:
# None Known                                                                                       524
# Within Critical Habitats                                                                         124
# Within Critical Habitats\n Within National Protected Areas                                        57
# Within Indigenous Peoples' Lands\n Within Critical Habitats                                       45
# Within Indigenous Peoples' Lands                                                                  41
# Within Indigenous Peoples' Lands\n Within Critical Habitats\n Within National Protected Areas     34
# Within National Protected Areas                                                                   19
# Within Indigenous Peoples' Lands\n Within National Protected Areas                                13
# Name: SENSITIVE TERRITORY OVERLAP, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot('SENSITIVE TERRITORY OVERLAP', data = china_data, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
china_data['Country'].unique()
# Out:
# array(['Angola', 'Brazil', 'Suriname', 'Cambodia', 'Kenya',
#        'Congo, Democratic Republic of the', 'Laos', 'Bangladesh',
#        'Nigeria', 'Benin', 'Zambia', 'Bahamas', "Cote d'Ivoire",
#        'Ethiopia', 'Djibouti', 'Indonesia', 'Togo', 'Philippines',
#        'Myanmar', 'Mozambique', 'Eritrea', 'Ukraine', 'South Sudan',
#        'Sudan', 'Kyrgyz Republic', 'Uzbekistan', 'Ecuador', 'Mauritania',
#        'Kazakhstan', 'Jordan', 'Niger', 'Mauritius', 'Pakistan', 'Mali',
#        'Hungary', 'Serbia', 'Belarus', 'Morocco', 'Regional', 'Malawi',
#        'Egypt', 'Tanzania', 'Congo, Republic of the', 'Fiji', 'Nepal',
#        'Rwanda', 'Ghana', 'Senegal', 'Sri Lanka', 'Argentina', 'Guyana',
#        'Trinidad and Tobago', 'Maldives', 'Bolivia', 'Vietnam', 'Gabon',
#        'Montenegro', 'Papua New Guinea', 'Samoa', 'Iran', 'Cameroon',
#        'Venezuela', 'Timor-Leste', 'Peru', 'Tajikistan', 'Malaysia',
#        'Dominican Republic', 'Uganda', 'Russian Federation', 'Madagascar',
#        'Turkmenistan', 'Jamaica', 'Gambia', 'Lesotho', 'Zimbabwe',
#        'Mongolia', 'Cuba', 'Guinea', 'Macedonia', 'Vanuatu',
#        'Equatorial Guinea', 'Grenada', 'South Africa', 'Namibia', 'Chad',
#        'Tonga', 'Barbados', 'Liberia', 'Costa Rica', 'Antigua & Barbuda',
#        'Comoros', 'Mexico', 'Tunisia', 'Bosnia & Herzegovina'],
#       dtype=object)

# %%
china_data['Country'].value_counts()
# Out:
# Angola                  115
# Ethiopia                 34
# Cambodia                 31
# Sri Lanka                30
# Indonesia                30
#                        ...
# Malaysia                  1
# Peru                      1
# Hungary                   1
# Jordan                    1
# Bosnia & Herzegovina      1
# Name: Country, Length: 94, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot('Country', data = china_data, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
def amount(a):
    y=a
    if ',' in a:
        a=a.replace(',','')
    a=float(a[1:-1])
    if y[-1]=='M':
        return a*1000000
    elif y[-1]=='B':
        return a*1000000000
    else:
        return 'Please check'

# %%
china_data['AMOUNT']=china_data['AMOUNT'].apply(amount)

# %%
china_data.head()
# Out:
#                                                Title  YEAR        AMOUNT  \
# 0            “Lar Patriota" Infrastructure (Phase 1)  2011  5.000000e+07
# 1  10-Year Oil Supply Plan (10Mt/Year), "Oil for ...  2009  7.000000e+09
# 2                               1000 housing project  2012  4.700000e+07
# 3  115kV Transmission Line and Substation from Ph...  2009  4.750000e+08
# 4            151 Multisector infrastructure projects  2016  6.000000e+08
#
#      LENDER                 BORROWER                      SECTOR  \
# 0       CDB               Government                   Transport
# 1       CDB                Petrobras       Extraction, pipelines
# 2  ExImBank               Government                  Government
# 3  ExImBank  Electricite Du Cambodge                       Power
# 4       CDB    Central Bank of Kenya  Mulit-sector/discretionary
#
#   SENSITIVE TERRITORY OVERLAP   Country
# 0                  None Known    Angola
# 1                  None Known    Brazil
# 2                  None Known  Suriname
# 3                  None Known  Cambodia
# 4                  None Known     Kenya

# %%
plt.figure(figsize=(20,8))
sns.barplot(x = 'Country',y = 'AMOUNT', data = china_data.head(500))
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(20,8))
fig = px.bar(x = 'Country',y = 'AMOUNT', data = china_data.head(500))
plt.xticks(rotation = 90)
plt.show()

# %%
fig4 = px.bar(china_data.head(500), 
                    x = "Country", y = "AMOUNT")
fig4.show()
# Out:
# <div>                            <div id="5e164380-2118-453c-823c-d17794538d8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e164380-2118-453c-823c-d17794538d8c")) {                    Plotly.newPlot(                        "5e164380-2118-453c-823c-d17794538d8c",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>AMOUNT=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["Angola","Brazil","Suriname","Cambodia","Kenya","Kenya","Cambodia","Cambodia","Congo, Democratic Republic of the","Laos","Laos","Cambodia","Angola","Bangladesh","Nigeria","Benin","Cambodia","Zambia","Laos","Bahamas","Cote d'Ivoire","Cote d'Ivoire","Cote d'Ivoire","Cote d'Ivoire","Cote d'Ivoire","Nigeria","Nigeria","Nigeria","Nigeria","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Djibouti","Indonesia","Togo","Benin","Cote d'Ivoire","Philippines","Myanmar","Mozambique","Eritrea","Ukraine","South Sudan","Zambia","Benin","Sudan","Sudan","Kyrgyz Republic","Kyrgyz Republic","Angola","Uzbekistan","Ecuador","Cote d'Ivoire","Mauritania","Kazakhstan","Jordan","Kazakhstan","Congo, Democratic Republic of the","Ethiopia","Niger","Mauritius","Indonesia","Pakistan","Mali","Indonesia","Bangladesh","Pakistan","Philippines","Nigeria","Kazakhstan","Mozambique","Hungary","Serbia","Indonesia","Angola","Congo, Democratic Republic of the","Belarus","Morocco","Brazil","Regional","Malawi","Malawi","Kyrgyz Republic","Kyrgyz Republic","Kyrgyz Republic","Sudan","Ethiopia","Ethiopia","Egypt","Tanzania","Regional","Congo, Democratic Republic of the","Congo, Republic of the","Fiji","Nepal","Rwanda","Ghana","Ghana","Senegal","Pakistan","Sri Lanka","Congo, Democratic Republic of the","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Cambodia","Ghana","Argentina","Angola","Angola","Angola","Angola","Togo","Indonesia","Uzbekistan","Sri Lanka","Pakistan","Guyana","Philippines","Mozambique","Trinidad and Tobago","Maldives","Belarus","Laos","Mozambique","Cambodia","Indonesia","Indonesia","Indonesia","Bolivia","Vietnam","Ecuador","Ecuador","Sri Lanka","Sri Lanka","Zambia","Cote d'Ivoire","Argentina","Maldives","Gabon","Congo, Republic of the","Angola","Montenegro","Cambodia","Cambodia","Cambodia","Cambodia","Papua New Guinea","Sri Lanka","Laos","Samoa","Zambia","Serbia","Benin","Iran","Cameroon","Angola","Cameroon","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Ethiopia","Venezuela","Zambia","Senegal","Bangladesh","Kyrgyz Republic","Zambia","Zambia","Uzbekistan","Ecuador","Ecuador","Maldives","Maldives","Maldives","Bangladesh","Bangladesh","Zambia","Mozambique","Congo, Republic of the","Timor-Leste","Ethiopia","Ecuador","Ecuador","Ecuador","Peru","Venezuela","Venezuela","Venezuela","Venezuela","Djibouti","Djibouti","Cameroon","Bolivia","Congo, Republic of the","Tajikistan","Vietnam","Vietnam","Vietnam","Togo","Ghana","Senegal","Ghana","Ghana","Angola","Angola","Cameroon","Cameroon","Sri Lanka","Guyana","Malaysia","Indonesia","Congo, Democratic Republic of the","Egypt","Bolivia","Bolivia","Sudan","Sudan","Bolivia","Serbia","Dominican Republic","Uganda","Angola","Angola","Angola","Angola","Belarus","Belarus","Belarus","Cameroon","Pakistan","Cameroon","Angola","Angola","Angola","Angola","Angola","Mozambique","Mozambique","Ecuador","Kazakhstan","Kazakhstan","Uganda","Kenya","Morocco","Uganda","Kenya","Ecuador","Ethiopia","Ethiopia","Russian Federation","Pakistan","Bangladesh","Maldives","Cambodia"," ...

# %%
fig5 = px.bar(china_data.tail(358), 
                    x = "Country", y = "AMOUNT")
fig5.show()
# Out:
# <div>                            <div id="95c72845-ca0b-4114-a8f8-6ba2468c6e14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95c72845-ca0b-4114-a8f8-6ba2468c6e14")) {                    Plotly.newPlot(                        "95c72845-ca0b-4114-a8f8-6ba2468c6e14",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>AMOUNT=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["Congo, Republic of the","Congo, Republic of the","Namibia","Regional","Angola","Rwanda","Myanmar","Chad","Chad","Congo, Democratic Republic of the","Angola","Fiji","Indonesia","Kenya","Kenya","Kenya","Kenya","Kenya","Laos","Laos","Laos","Laos","Laos","Laos","Laos","Bahamas","Guinea","Uganda","Mali","Suriname","Senegal","Zimbabwe","Cameroon","Angola","Papua New Guinea","Suriname","Samoa","Samoa","Kenya","Cote d'Ivoire","Nigeria","Tonga","Cambodia","Congo, Republic of the","Congo, Republic of the","Congo, Republic of the","Senegal","Ghana","Cameroon","Congo, Republic of the","Cameroon","Papua New Guinea","Zambia","Pakistan","Pakistan","Zimbabwe","Zimbabwe","Venezuela","South Sudan","Sudan","Togo","Togo","Mali","Togo","Zambia","Sri Lanka","Kyrgyz Republic","Kyrgyz Republic","Jamaica","Sri Lanka","Mauritania","Sudan","Angola","Serbia","Ecuador","Ecuador","Brazil","Brazil","Russian Federation","Venezuela","Bangladesh","Kenya","Kenya","Kenya","Ethiopia","Ethiopia","Pakistan","Venezuela","Kyrgyz Republic","Kyrgyz Republic","Equatorial Guinea","Congo, Republic of the","Papua New Guinea","Indonesia","Bangladesh","Indonesia","Laos","Pakistan","Pakistan","Jamaica","Indonesia","Indonesia","Indonesia","Indonesia","Uzbekistan","Indonesia","Bangladesh","Venezuela","Angola","Indonesia","Pakistan","Cambodia","Trinidad and Tobago","Bangladesh","Indonesia","Nepal","Kazakhstan","Ghana","Ecuador","Niger","Cameroon","Cameroon","Brazil","Brazil","Regional","Regional","Sri Lanka","Kenya","Bangladesh","Myanmar","Zambia","Togo","Ukraine","Montenegro","Uzbekistan","Uzbekistan","Uzbekistan","Vietnam","Kenya","Pakistan","Argentina","Iran","Russian Federation","Angola","Bangladesh","Madagascar","Belarus","Sri Lanka","Sri Lanka","Sri Lanka","Sri Lanka","Sri Lanka","Sri Lanka","Kenya","Tajikistan","Argentina","Cambodia","Angola","Cambodia","Barbados","Cambodia","Angola","Indonesia","Angola","Argentina","Belarus","Congo, Democratic Republic of the","Congo, Democratic Republic of the","Congo, Democratic Republic of the","Jamaica","Gabon","Senegal","Jamaica","Vanuatu","Angola","Angola","Angola","Angola","Angola","Vanuatu","Fiji","Fiji","Liberia","Philippines","Bolivia","Angola","Zimbabwe","Cambodia","Cambodia","Cambodia","Cambodia","Bolivia","Russian Federation","Laos","Costa Rica","Argentina","Cuba","Angola","Belarus","Angola","Russian Federation","Sudan","Kenya","Kenya","Kenya","Ethiopia","Congo, Democratic Republic of the","Cambodia","Ecuador","Bangladesh","Myanmar","Mauritius","Belarus","Zambia","Argentina","Kenya","Regional","Regional","Regional","Ethiopia","Zambia","Regional","Egypt","Egypt","Ethiopia","Mozambique","Egypt","Cameroon","Togo","Zambia","Indonesia","Angola","Angola","Angola","Angola","Angola","Ecuador","Niger","Guinea","Guinea","Cote d'Ivoire","Cameroon","Sudan","Sudan","Sri Lanka","Philippines","Brazil","Angola","Angola","Antigua & Barbuda","Cambodia","Maldives","Papua New Guinea","Cambodia","Philippines","Angola","Angola","Angola","Indonesia","Brazil","Sri Lanka","Indonesia","Serbia","Indonesia","Ghana","Indonesia","Mali","Pakistan","Mongolia","Comoros","Zimbabwe","Indonesia","Vietnam","Pakistan","Sri Lanka","Pakistan","Cambodia","Senegal","Kazakhstan","Cote d'Ivoi ...

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x = 'Country',y = 'YEAR', data = china_data)
plt.xticks(rotation = 90)
plt.show()

# %%
fig6 = px.histogram(china_data, 
                    x = "Country", color = "SECTOR")
fig6.show()
# Out:
# <div>                            <div id="00d6a663-6eba-4587-af3f-385bb836ad3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00d6a663-6eba-4587-af3f-385bb836ad3b")) {                    Plotly.newPlot(                        "00d6a663-6eba-4587-af3f-385bb836ad3b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"SECTOR=Transport<br>Country=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Transport","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Transport","offsetgroup":"Transport","orientation":"v","showlegend":true,"type":"histogram","x":["Angola","Angola","Nigeria","Cambodia","Cote d'Ivoire","Cote d'Ivoire","Nigeria","Nigeria","Nigeria","Nigeria","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Ethiopia","Djibouti","Cote d'Ivoire","Ukraine","South Sudan","Benin","Sudan","Kyrgyz Republic","Kyrgyz Republic","Cote d'Ivoire","Mauritania","Kazakhstan","Congo, Democratic Republic of the","Indonesia","Mali","Hungary","Serbia","Angola","Congo, Democratic Republic of the","Morocco","Kyrgyz Republic","Kyrgyz Republic","Ethiopia","Ethiopia","Congo, Democratic Republic of the","Fiji","Rwanda","Sri Lanka","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Cambodia","Angola","Sri Lanka","Guyana","Maldives","Laos","Cambodia","Indonesia","Sri Lanka","Sri Lanka","Maldives","Montenegro","Cambodia","Cambodia","Cambodia","Cambodia","Sri Lanka","Laos","Zambia","Serbia","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Zambia","Bangladesh","Ethiopia","Djibouti","Sri Lanka","Guyana","Malaysia","Congo, Democratic Republic of the","Bolivia","Sudan","Sudan","Bolivia","Belarus","Belarus","Belarus","Angola","Angola","Angola","Angola","Angola","Mozambique","Mozambique","Uganda","Pakistan","Maldives","Cambodia","Cambodia","Cambodia","Madagascar","Cambodia","Samoa","Fiji","Senegal","Congo, Republic of the","Congo, Republic of the","Djibouti","Papua New Guinea","Lesotho","Sri Lanka","Sri Lanka","Sri Lanka","Sri Lanka","Sri Lanka","Zimbabwe","Pakistan","Mongolia","Sri Lanka","Sri Lanka","Angola","Angola","Rwanda","Madagascar","Madagascar","Suriname","Indonesia","Jamaica","Ethiopia","Uganda","Pakistan","Pakistan","Pakistan","Bangladesh","Papua New Guinea","Kenya","Macedonia","Rwanda","Rwanda","Cameroon","Cameroon","Cameroon","Cameroon","Kyrgyz Republic","Nigeria","Angola","Angola","Gabon","Gabon","Eritrea","Angola","Angola","Angola","Angola","Angola","Angola","Vanuatu","Angola","Zambia","Zambia","Zambia","Zambia","Congo, Democratic Republic of the","Belarus","Nepal","Cameroon","Angola","Indonesia","Zambia","Zambia","Mozambique","Mozambique","Mozambique","Sri Lanka","Grenada","Congo, Republic of the","Zambia","Laos","Ethiopia","Argentina","Equatorial Guinea","Ethiopia","Zambia","Venezuela","Russian Federation","Angola","Namibia","Rwanda","Congo, Democratic Republic of the","Angola","Kenya","Kenya","Kenya","Bahamas","Suriname","Tonga","Cambodia","Congo, Republic of the","Congo, Republic of the","Congo, Republic of the","Papua New Guinea","Zambia","South Sudan","Sudan","Togo","Togo","Togo","Kyrgyz Republic","Kyrgyz Republic","Jamaica","Sri Lanka","Mauritania","Angola","Serbia","Pakistan","Kyrgyz Republic","Kyrgyz Republic","Congo, Republic of the","Uzbekistan","Pakistan","Nepal","Bangladesh","Montenegro","Uzbekistan","Uzbekistan","Argentina","Iran","Russian Federation","Angola","Belarus","Sri Lanka","Sri Lanka","Sri Lanka","Sri Lanka","Sri Lanka","Sri Lanka","Argentina","Cambodia","Angola","Cambodia","Cambodia","Angola","Argentina","Congo, Democratic Republic of the","Congo, Democratic Republic of the","Congo, Democratic Republic of the","Jamaica","Gabon","Senegal","Jamaica","Vanuatu","Angola","Angola","Angola","Ango ...

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=90)
data=china_data.groupby('YEAR').sum().reset_index().sort_values('YEAR').sort_values('YEAR')
display(data)
sns.barplot(data=data,x='YEAR',y='AMOUNT',palette='spring')
plt.show()
# Out:
#     YEAR        AMOUNT
# 0   2008  7.565000e+09
# 1   2009  6.240000e+10
# 2   2010  4.123500e+10
# 3   2011  3.394900e+10
# 4   2012  3.488600e+10
# 5   2013  4.185200e+10
# 6   2014  4.839100e+10
# 7   2015  5.110400e+10
# 8   2016  7.500100e+10
# 9   2017  4.924100e+10
# 10  2018  1.258300e+10
# 11  2019  3.940000e+09

# %%
plt.figure(figsize=(15,10))
plt.suptitle('top 25 countries on which china invested the most(world wide)',size=20,weight='bold')
data=china_data.groupby('Country').sum().reset_index().sort_values('AMOUNT',ascending=False)[['Country','AMOUNT']]
plt.subplot(1,2,1)
plt.xticks(rotation=90)
sns.barplot(data=data.head(25),x='Country',y='AMOUNT')
plt.subplot(1,2,2)
plt.axis('off')
plt.tight_layout()
plt.table(cellText=data.head(25).values, colLabels=data.columns, loc='center')

# %%
plt.figure(figsize=(15,10))
plt.suptitle("top 25 countrie's Government on which china invested the most(world wide)",size=20,weight='bold')
data=china_data[china_data['BORROWER']=='Government'].groupby('Country').sum().reset_index().sort_values('AMOUNT',ascending=False)[['Country','AMOUNT']]
plt.subplot(1,2,1)
plt.xticks(rotation=90)
sns.barplot(data=data.head(25),x='Country',y='AMOUNT')
plt.subplot(1,2,2)
plt.axis('off')
plt.tight_layout()
plt.table(cellText=data.head(25).values, colLabels=data.columns, loc='center')

# %%
import textwrap

# %%
country='Pakistan'
data=china_data[china_data['Country']==country]
ax=plt.figure(figsize=(15,10))
plt.suptitle(f"China's investments on {country}",weight='bold',size=20)
plt.subplot(2,2,1)
plt.title('Year-wise Investment')
sns.lineplot(data=data.groupby('YEAR').sum().reset_index(),x='YEAR',y='AMOUNT',color='r')
plt.subplot(2,2,2)
plt.title('Sector-wise Investment')
data['SECTOR'].value_counts().plot.pie(autopct='%.2f%%')
plt.subplot(2,2,3)
plt.title('Borrower-wise Amount invested')
plt.xticks(rotation=90)
ax=sns.barplot(data=data.groupby('BORROWER').sum().reset_index(),x='BORROWER',y='AMOUNT')
labels = [textwrap.fill(label.get_text(), 12) for label in ax.get_xticklabels()]
ax.set_xticklabels(labels)
plt.subplot(2,2,4)
plt.title('YEAR-wise Amount invested')
ax=sns.barplot(data=data,x='YEAR',y='AMOUNT',hue='SECTOR',ci=False)
labels = [textwrap.fill(label.get_text(), 12) for label in ax.get_xticklabels()]
display(data.sort_values('AMOUNT',ascending=False)[['YEAR','AMOUNT']].reset_index(drop=True))
# Out:
#     YEAR        AMOUNT
# 0   2009  6.900000e+09
# 1   2014  6.500000e+09
# 2   2017  6.100000e+09
# 3   2016  2.900000e+09
# 4   2015  2.700000e+09
# 5   2015  2.700000e+09
# 6   2014  1.900000e+09
# 7   2014  1.600000e+09
# 8   2017  1.500000e+09
# 9   2017  1.200000e+09
# 10  2013  1.200000e+09
# 11  2016  9.560000e+08
# 12  2015  7.850000e+08
# 13  2015  5.760000e+08
# 14  2016  5.000000e+08
# 15  2012  4.480000e+08
# 16  2011  3.770000e+08
# 17  2008  3.270000e+08
# 18  2015  2.070000e+08
# 19  2008  2.000000e+08
# 20  2011  1.570000e+08
# 21  2017  7.600000e+07
# 22  2013  4.400000e+07
